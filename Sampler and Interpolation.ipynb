# %% [markdown]
# # Interpolation

# %% [markdown]
# Firstly, using the Gaussian distribution
#
# $$
# P(x|\mu, \sigma) = \frac{1}{\sqrt{2\pi}}\frac{e^{-\frac{\left(x-\mu\right)^2}{2\mu^2}}}{\sigma},
# $$
#
# and
#
# $$
# C(x) \propto Erf.
# $$
#
# Calculate the interpolated version of $P(x|\mu, \sigma)$ and $C(x)$, and compare them with the same functions in the library of your choice

# %%
import numpy as np
from numpy import array
import matplotlib.pyplot as plt
import stats_funcs.funcs as fs

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 16, 8

# %%
mu = 0
sigma = 1

x = np.linspace(-4, 4, 50)

pdf = [fs.gaussian(i, mu, sigma) for i in x]

pdf_inter = fs.interpolate(pdf, x)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Interpolation Comparisson')
ax1.bar(x, pdf, alpha = 0.4, label = 'Original $\{x_i\}$ with ' + f'N={len(pdf)} values.')
ax1.legend()
ax2.bar(pdf_inter[1], pdf_inter[0], alpha = 0.4, label = 'Interpolated $\{x_i\}$ with ' + f'N={len(pdf_inter[0])} values.')
ax2.legend()

# %%
erf = fs.cdf(fs.gaussian, x, (mu, sigma))
erf_inter = fs.interpolate(erf, x)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Interpolation Comparisson')
ax1.bar(x, erf, alpha = 0.4, label = 'Original $\{x_i\}$ with ' + f'N={len(erf)} values.')
ax1.legend()
ax2.bar(erf_inter[1], erf_inter[0], alpha = 0.4, label = 'Interpolated $\{x_i\}$ with ' + f'N={len(erf_inter[0])} values.')
ax2.legend()

# %%
x_0 = 1
sigma = 1

x = np.linspace(0, 10, 100)

skew = [fs.some_random_function(i, x_0, sigma) for i in x]

skew_inter = fs.interpolate(skew, x)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Interpolation Comparisson')
ax1.bar(x, skew, alpha = 0.4, label = 'Original $\{x_i\}$ with ' + f'N={len(skew)} values.')
ax1.legend()
ax2.bar(skew_inter[1], skew_inter[0], alpha = 0.4, label = 'Interpolated $\{x_i\}$ with ' + f'N={len(skew_inter[0])} values.')
ax2.legend()

# %%
cdf = fs.cdf(fs.some_random_function, x, (x_0, sigma))
cdf_inter = fs.interpolate(cdf, x)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Interpolation Comparisson')
ax1.bar(x, cdf, alpha = 0.4, label = 'Original $\{x_i\}$ with ' + f'N={len(cdf)} values.')
ax1.legend()
ax2.bar(cdf_inter[1], cdf_inter[0], alpha = 0.4, label = 'Interpolated $\{x_i\}$ with ' + f'N={len(cdf_inter[0])} values.')
ax2.legend()

# %% [markdown]
# # Sampler

# %% [markdown]
# Secondly, using a random sample generator from a uniform distribution, generate a random sample for $\widetilde{X}(U_i)$ and plot histogram over a continuous version of the Gaussian distribution (interpolated and library given).
#
# The sampler was created based on [Wikipedia's](https://en.wikipedia.org/wiki/Inverse_transform_sampling) article on **Inverse Transform Sampling**.
